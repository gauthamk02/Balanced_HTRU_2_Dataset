# %% [markdown]
# # Data preparation

# %% [markdown]
# ### Importing Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

data = pd.read_csv('HTRU_2.csv', header=None)
data.head()
# Out:
#             0          1         2         3         4          5          6  \
# 0  140.562500  55.683782 -0.234571 -0.699648  3.199833  19.110426   7.975532
# 1  102.507812  58.882430  0.465318 -0.515088  1.677258  14.860146  10.576487
# 2  103.015625  39.341649  0.323328  1.051164  3.121237  21.744669   7.735822
# 3  136.750000  57.178449 -0.068415 -0.636238  3.642977  20.959280   6.896499
# 4   88.726562  40.672225  0.600866  1.123492  1.178930  11.468720  14.269573
#
#             7  8
# 0   74.242225  0
# 1  127.393580  0
# 2   63.171909  0
# 3   53.593661  0
# 4  252.567306  0

# %%
"""
1. Mean of the integrated profile.
2. Standard deviation of the integrated profile.
3. Excess kurtosis of the integrated profile.
4. Skewness of the integrated profile.
5. Mean of the DM-SNR curve.
6. Standard deviation of the DM-SNR curve.
7. Excess kurtosis of the DM-SNR curve.
8. Skewness of the DM-SNR curve.
"""

#Adding Column Names
col_names = ["Mean_IP", "Std_IP", "Ex_Kurt_IP", "Skew_IP", "Mean_DM_SNR", "Std_DM_SNR", "Ex_Kurt_DM_SNR", "Skew_DM_SNR", "Class"]
data.columns = col_names
data.head()
# Out:
#       Mean_IP     Std_IP  Ex_Kurt_IP   Skew_IP  Mean_DM_SNR  Std_DM_SNR  \
# 0  140.562500  55.683782   -0.234571 -0.699648     3.199833   19.110426
# 1  102.507812  58.882430    0.465318 -0.515088     1.677258   14.860146
# 2  103.015625  39.341649    0.323328  1.051164     3.121237   21.744669
# 3  136.750000  57.178449   -0.068415 -0.636238     3.642977   20.959280
# 4   88.726562  40.672225    0.600866  1.123492     1.178930   11.468720
#
#    Ex_Kurt_DM_SNR  Skew_DM_SNR  Class
# 0        7.975532    74.242225      0
# 1       10.576487   127.393580      0
# 2        7.735822    63.171909      0
# 3        6.896499    53.593661      0
# 4       14.269573   252.567306      0

# %%
value_count = data["Class"].value_counts()
print(value_count)
# Out:
# 0    16259
# 1     1639
# Name: Class, dtype: int64

# %% [markdown]
# ### Creating new Dataframe with equal number of values in Class Column

# %%
data_new = pd.concat((data.loc[data["Class"] == 0].sample(n= value_count[1]), data.loc[data["Class"] == 1]), ignore_index= True)

#shuffling the rows
data_new = sklearn.utils.shuffle(data_new, random_state= 50).reset_index(drop=True)
data_new.head(20)
# Out:
#        Mean_IP     Std_IP  Ex_Kurt_IP    Skew_IP  Mean_DM_SNR  Std_DM_SNR  \
# 0    93.750000  40.657679    0.910555   2.164690     5.096990   28.217898
# 1    77.492188  36.010414    1.873517   6.508272     8.030936   37.252414
# 2   112.476562  58.971122    0.394276  -0.677985     3.253344   18.038750
# 3    81.656250  43.920105    1.320341   3.307269    13.639632   47.175894
# 4   110.054688  45.564053    0.379363   0.133880     1.261706   13.032154
# 5   115.929688  50.650176    0.102399   0.099721     1.397157   13.723267
# 6    94.695312  46.575134    0.335470   0.153277     3.459866   24.042832
# 7    49.015625  43.054287    3.142802  10.589181    12.489967   41.171808
# 8   106.718750  48.599919    0.483138   0.060912     6.269231   29.929925
# 9    25.132812  34.706666    4.815267  25.225663    91.404682   86.555964
# 10   37.304688  41.065793    3.653734  13.722333    51.106187   64.889922
# 11  126.273438  51.964188    0.059317  -0.175436     3.941472   22.211621
# 12   33.914062  36.319766    4.561126  22.331550    80.230769   83.172918
# 13  127.765625  50.480733    0.121002  -0.233421     3.317726   22.269730
# 14   74.750000  35.627193    1.940598   7.212272    20.446488   57.341621
# 15   51.179688  33.578135    3.540393  18.441809    47.286789   72.858608
# 16  122.976562  40.533448    0.160999   0.873384     3.050167   20.115906
# 17   64.453125  46.452910    2.723048   7.110334    97.770903   64.299110
# 18  100.148438  41.157869    0.618730   1.524410     1.732441   16.486956
# 19  152.765625  50.579993   -0.166093  -0.038770     2.380435   15.080273
#
#     Ex_Kurt_DM_SNR  Skew_DM_SNR  Class
# 0         5.916694    35.542304      1
# 1         5.081888    25.683906      1
# 2         8.181099    82.644551      0
# 3         3.604874    12.059129      1
# 4        13.294267   202.930061      0
# 5        12.605644   184.778788      0
# 6         7.285706    53.769442      1
# 7         3.778334    14.256524      1
# 8         6.026228    38.468864      1
# 9         0.390899    -1.237221      1
# 10        1.338573     1.060300      1
# 11        7.042359    53.867952      0
# 12        0.558920    -1.100623      1
# 13        8.175451    72.777561      0
# 14        2.659362     5.527676      1
# 15        1.386723     0.620480      1
# 16        7.769908    67.786557      0
# 17        1.093908    -0.047664      1
# 18       12.498927   168.368092      0
# 19        9.824548   120.328729      0

# %%
data_new["Class"].value_counts()
# Out:
# 1    1639
# 0    1639
# Name: Class, dtype: int64

# %% [markdown]
# ### Writing new Dataframe to File

# %%
data_new.to_csv('HTRU_2_modified.csv', index=False)
